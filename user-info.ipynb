# %%
import pandas as pd

user_data = pd.read_csv('com_cheese_api/user/data/users.csv', encoding='UTF-8', thousands=',')

# %%
user_data
# Out:
#        Unnamed: 0  user_id user_gender  user_age  cheese_code  \
# 0               0  2391853           M        40          114
# 1               1  1799897           F        40          114
# 2               2  1614947           F        50          189
# 3               3  1614947           F        50          189
# 4               4  1614947           F        50       804126
# ...           ...      ...         ...       ...          ...
# 36868       36868  6159545           F        30       847511
# 36869       36869  1942828           M        40       847554
# 36870       36870  1942828           M        40       847554
# 36871       36871  6284056           M        30       847555
# 36872       36872  1306045           F        40       847556
#
#                                              cheese_name category  \
# 0                                         가고시마 현미흑초 720㎖     건강식품
# 1                                         가고시마 현미흑초 720㎖     건강식품
# ...

# %%
user_data['PD_NM'].value_counts()
# Out:
# 풀무원 생수 2L x 6페트                                                2212
# 부드럽고 맛있는 닭가슴살 11종 (100g,120g,130g,150g*1팩) - 2.부드러운 훈제 닭가슴살    1264
# [본사직영] 고려은단 비타민C 1000 600정                                     1237
# [제주]삼다수 2L*6 - 제주삼다수 2L*6EA                                     902
# 굿밸런스 라이트밀 도시락 6종*1팩 골라담기 - 05_시래기 표고버섯 솥밥 & 청양고추맛 닭가슴살 스테이크     760
#                                                                ...
# 천지양 튼튼쑥쑥키즈 홍삼 20ml x 30포 x 2박스                                    1
# 하루기초 헛개열매진액                                                       1
# [농협] 푸짐한 정품 안동 세척사과 대용량1호 8kg                                     1
# 네이처스플러스 애니멀퍼레이드 멀티비타민 + 칼슘                                        1
# 슈퍼 C-1000 비타민C 1000mg (60정)                                       1
# Name: PD_NM, Length: 2746, dtype: int64

# %%
element_count = {}

for item in user_data['PD_NM']:
    element_count.setdefault(item,0)
    element_count[item] += 1
    
print(element_count)
# Out:
# {'가고시마 현미흑초 720㎖': 2, '신가네여주농장 여주즙 100ml 50팩 1박스 청정지역철원재배생산': 4, '새우볶음밥 270g': 9, 'CAVENDISH 캐빈디쉬 해쉬브라운 1.2kg': 12, '참치김치볶음밥 300g': 17, '새우볶음밥 300g': 28, '올바른 석류즙 100포(실속포장)': 154, 'CJ 한뿌리 홍삼 10입 (손잡이형) - 홍삼한뿌리': 2, '글램카페 오리지널 2BOX (5g×30포×2박스/총60포)': 1, '맥스 멀티비타민앤미네랄 포 틴 90정 2통(6개월분/청소년 종합비타민)': 6, '맥스 칼슘 마그네슘 비타민D&C플러스 120캅셀x2통': 1, '유기농오분도미밥(210g)': 2, '영동 거봉포도(공중부양박스) 4kg': 5, '[초록마을] 착한농부참외(1kg)': 2, '착한농부실속배(3~5입/봉)': 18, '[초록마을] [기획]착한농부방울토마토두팩묶음(500g×2입)': 6, '찬마루 서울반가 포기김치(10kg) / 무료배송 - 서울반가  포기김치': 12, '[초록마을] 착한농부참외(1.2kg)': 3, '[아리알찬]아삭아삭 당도높은 신고배 7.5kg(14-15과)': 1, '여에스더 유산균 프로바이오틱스 클래식 1병': 6, '[#텐텐] VAP 항산화젤리 4주분 (14포*2)': 2, '밀크시슬 Milk Thistle (60캡슐) - GNC 밀크시슬 Milk Thistle / 60캡슐': 34, 'SOM 냉동 찐밤(증숙밤) 2kg(1kgx2팩)/간편하게 즐기세요': 1, '로스티드피넛 500g - 로스티드피넛 500g': 6, '매일매일 건강채움 / 케틀콘 140g 달콤하고 고소한 옥수수 한알 한알 살아있는 케틀콘! - 케틀콘': 3, '[매일매일건강채움]커피땅콩 500g - 커피땅콩500g': 6, '호두 400g+400g / 견과 견과류 / 무료배송': 279, '[그린너트]볶음땅콩 500g - 볶음땅콩 500g': 2, '[그린너트] 볶음땅콩반태 500g - 볶음땅콩반태 500g': 3, '
# ...

# %%
user_data['category'].value_counts()
# Out:
# 건강식품    15428
# 음료       7084
# 축산물      4383
# 냉동식품     4288
# 과일       3549
# 냉장식품     2141
# Name: category, dtype: int64

# %%
user_data['sub1_category'].value_counts()
# Out:
# 영양제          8843
# 생수           5670
# 닭고기류         4351
# 냉동간편식        4288
# 홍삼/인삼가공식품    2692
# 견과류          2163
# 포장반찬         2141
# 건강진액         2031
# 건강보조식품       1862
# 국산과일         1386
# 두유            910
# 기능성음료         504
# 축산선물세트         32
# Name: sub1_category, dtype: int64

# %%
user_data['CLAC3_NM'].value_counts()
# Out:
# 생수           5663
# 닭가슴살         4239
# 일반비타민        2933
# 기타냉동간편식      2823
# 김치류          2045
#              ...
# 감               2
# 볶음반찬            1
# 비타민/에너지음료       1
# 오리고기            1
# 닭아랫날개(윙)        1
# Name: CLAC3_NM, Length: 83, dtype: int64

# %%
element_count = {}

for item in user_data['CLAC3_NM']:
    element_count.setdefault(item,0)
    element_count[item] += 1
    
print(element_count)
# Out:
# {'기타영양제': 1533, '채소즙': 507, '냉동밥': 491, '기타냉동간편식': 2823, '과일즙': 652, '혼합즙': 644, '다이어트보조식품': 1522, '종합영양제': 753, '기타국산과일류': 766, '사과': 246, '참외': 65, '배': 71, '방울토마토': 108, '김치류': 2045, '유산균/프로바이오틱스': 1800, '홍삼근': 5, '밤': 291, '땅콩': 129, '기타견과류': 538, '호두': 394, '볶음탕용닭': 5, '냉동국탕류': 413, '일반비타민': 2933, '냉동만두': 320, '삼계탕용닭': 99, '토마토': 31, '냉동튀김': 121, '자연유래영양제': 177, '글루코사민': 27, '혼합견과': 587, '냉동피자': 2, '닭가슴살': 4239, '생수': 5663, '칼슘/미네랄': 396, '오메가3/기타추출오일': 379, '홍삼정/분말/환': 638, '일반두유': 907, '인삼가공식품': 95, '루테인': 528, '기타기능성음료': 407, '엽산/철분': 74, '탄산수': 7, '홍삼액': 924, '홍삼/인삼혼합세트': 67, '영양제세트': 230, '미용보조식품': 297, '냉동디저트': 5, '메론': 18, '아몬드': 181, '한방음료': 92, '절임반찬': 72, '닭윗날개(봉)': 2, '운동보조식품': 41, '발효원액': 228, '어린이홍삼': 950, '냉동핫도그': 13, '단무지': 8, '복숭아': 14, '홍삼절편': 13, '한우선물세트': 29, '젓갈': 15, '잣': 24, '캐슈넛': 14, '감': 2, '육가공품선물세트': 3, '귤류': 15, '마카다미아': 5, '냉동떡볶이': 97, '포도': 3, '매실': 21, '건강보조식품세트': 2, '딸기': 20, '자두': 6, '오리고기': 1, '발포비타민': 13, '닭다리': 2, '냉동부침': 3, '숙취해소음료': 4, '닭아랫날
# ...

# %%
import pandas as pd

user_list = pd.read_csv('users.csv', encoding='utf-8', thousands=',')

# %%
user_list
# Out:
#        Unnamed: 0  user_id user_gender  user_age  cheese_code  \
# 0               0  2391853           M        40          114
# 1               1  1799897           F        40          114
# 2               2  1614947           F        50          189
# 3               3  1614947           F        50          189
# 4               4  1614947           F        50       804126
# ...           ...      ...         ...       ...          ...
# 36868       36868  6159545           F        30       847511
# 36869       36869  1942828           M        40       847554
# 36870       36870  1942828           M        40       847554
# 36871       36871  6284056           M        30       847555
# 36872       36872  1306045           F        40       847556
#
#                                              cheese_name category  \
# 0                                         가고시마 현미흑초 720㎖     건강식품
# 1                                         가고시마 현미흑초 720㎖     건강식품
# ...
